# %% [markdown]
# <a href="https://colab.research.google.com/github/jihye-jeon2/python/blob/main/02_%EB%B3%80%EC%88%98%EC%99%80_%EC%97%B0%EC%82%B0%EC%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 02. 변수와 연산자

# %% [markdown]
# ## 1. 변수 (Variable)
#
# * **개념**: 프로그램 실행 중 값을 저장하는 메모리 공간.
# * **특징**: 변수에는 하나의 값만 저장되며, 새로운 값을 넣으면 기존 값은 삭제됨.
# * **대입 연산자 (`=`)**: 오른쪽의 값을 왼쪽 변수에 저장함.
# * 예: `age = 20` (age라는 변수에 20을 대입)

# %% [markdown]
# 변수는 변하는 값
# 하나만 지정가능, 새로운 값이 들어오면 기존의 것은 삭제됨
#
# print('age') ->문자열
#
# age=20
# print(age) ->변수
#
# a,b,c=7,11,19<br>
# print(a,b,c)
# <br>결과 7 11 19<br>
# 쉼표를 통해서 여러개 지정가능<br>
# <br>
# 복합대입연산자 // 연산한 값을 다시 대입하는 연산자<br>
# a=5<br>
# a+=7   //a = a + 7,a값 변경 <br>
# print(a)  //12

# %%
age = 20
print(age)
print(type(age))
# Out:
# 20
# <class 'int'>

# %%
age=20
print(age)

age=30
print(age)
# Out:
# 20
# 30

# %%
age = 20
print(age)
# Out:
# 20

# %%
name='홍길동'
age=18
print(name,'나이는:',age)
# Out:
# 홍길동 나이는: 18

# %%
a = b = c = 7
print(a,b,c)

a,b,c = 7,11,19
print(a,b,c)
# Out:
# 7 7 7
# 7 11 19

# %%
a = 5
a += 7
print(a)
# Out:
# 12

# %%
a,b=2,3
a+=b
print(a)

a,b=2,3
a -= b
print(a)
# Out:
# 5
# -1

# %%
#복합 대입 연산자(연산한 값을 다시 대입하는 연산자)
a,b = 2,3
a *= b #a=a*b
print(a)

a,b=3,2
a/= b #a=a/b
print(a)

a,b = 7,3
a //= b #a=a//b 몫을 a에다가 저장
print(a)

a,b = 7,9
a %= b  #a=a%b
print(a)
# Out:
# 6
# 1.5
# 2
# 7

# %%
a=100
a +=10 # a = a+10
print(a)

a*=2 # 현재 a = 110 a=a*2
print(a) #220

a // 7 # 현재 a = 220 , a=a//7 a를 7로 나눈 몫
print(a) #31

a %= 7 # 현재 a 는 31 ,  a = a%7 a를 7로 나눈 나머지
print(a) #3
# Out:
# 110
# 220
# 220
# 3

# %% [markdown]
# ### 변수 이름 만드는 규칙
#
#
# 1.   첫번째글자는 문자또는 밑줄, 나머지 글자는 문자,숫자,밑줄(_)이어야 함 즉, 숫자는 변수이름 첫글자로 x
#
# 2.   영어 대소문자 구분o
#
# 3.   키워드(예약어)를 변수이름으로 사용x
# *   키워드(keywordd) -> 프로그래밍 언어에서 사용하기 위해 쓰임새를 미리 정해놓은 단어(False,True,and,as,assert,if,import,in,is,lambda,nonlocal,raise,return,try,or,not,while,with,yield,None,class,continue 등

# %%
#두 변수의 값 교환하기
a=7
b=11
a,b = b,a #a변수에는 b변수값, b변수에는 a 변수 값
print(a,b) # 11 7
# Out:
# 11 7

# %%
#배수 구하기
a = 3
print(a)

a += 3 #a= a+3
print(a) #6

a+=3 #a= a+3
print(a) #9
# Out:
# 3
# 6
# 9

# %% [markdown]
# ## 2. 자료형 (Data Type)
#
# 데이터의 종류에 따라 적절한 자료형을 사용해야 합니다.
#
# * **정수형 (int)**: 소수점이 없는 숫자 (예: 10, -5)
# * **실수형 (float)**: 소수점이 있는 숫자 (예: 3.14, 0.5)
# * **문자열 (str)**: 따옴표(`'`, `"`)로 감싸진 텍스트 (예: "Hello", 'Python')
# * **불형 (bool)**: 참(`True`) 또는 거짓(`False`)을 나타냄

# %% [markdown]
# ### 자료형
#
#
# 1.   기본자료형
# 정수,부동서수점수,문자열,불
# 2.   구조적 자료형
# 리스트[10,20],딕셔너리,튜플
#
# *   무슨 차이인가??
# print(type(3.14)) -> type() 자료형 알수 있음 // float

# %%
print(type(2026)) #int(정수)

print(type(3.14)) #float(실수)

print(type('python')) #str(문자열)

print(type(True)) #bool(boolean)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 20
b = 0o34 #8진수
c = 0xA1 #16진수
d = 0b1110 #2진수

print(a,b,c,d)
# Out:
# 20 28 161 14

# %%
a = 3.14
#e5 무엇인가?
b = 1.23e5   # 소수점 뒤로 5칸 -> 123000.0

c = 123000.0e-5   # 소수점 앞으로 5칸 1.23
print(a,b,c)
# Out:
# 3.14 123000.0 1.23

# %% [markdown]
# ## 3. 입력과 출력
#
# * **출력 (`print`)**: 변수나 값을 화면에 표시.
# * `print('age')`는 문자열 출력, `print(age)`는 변수 값 출력.
#
# * **입력 (`input`)**: 사용자로부터 데이터를 입력받음.
# * **주의**: `input()`으로 받은 데이터는 기본적으로 **문자열**로 처리되므로, 계산이 필요하면 `int()`나 `float()`로 변환해야 함.

# %%
name = input('이름')
age = input('나이를 입력하세요')
print(name,'나이: ',age)
# Out:
# 이름홍길동
# 나이를 입력하세요20
# 홍길동 나이:  20

# %%
a = input('정수: ')
b = input('정수: ')
print(a - b) #오류 -> str - str input(string)으로 컴퓨터가 받아들임 // TypeError: unsupported operand type(s) for -: 'str' and 'str'
# Out:
# 정수: 5
# 정수: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-987163050.py in <cell line: 0>()
#       1 a = input('정수: ')
#       2 b = input('정수: ')
# ----> 3 print(a - b) #오류 -> str - str input(string)으로 컴퓨터가 받아들임
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
try:
    a = int(input('첫 번째 정수를 입력하세요: '))
    b = int(input('두 번째 정수를 입력하세요: '))
    print(a - b)
except ValueError:
    print("오류: 유효하지 않은 정수 입력입니다. 빈 문자열이나 숫자가 아닌 값을 입력할 수 없습니다.")
    print("예: '5'와 같은 정수를 입력해야 합니다.")
# Out:
# 첫 번째 정수를 입력하세요: 5
# 두 번째 정수를 입력하세요: 3
# 2

# %%
minute = float(input('분 단위 시간: '))
second = minute * 60
print(second,  '초')
# Out:
# 분 단위 시간: 4
# 240.0 초

# %%
print('반갑습니다')
score = 99
print('성적은',score,'입니다.')
# Out:
# 반갑습니다
# 성적은 99 입니다.

# %%
a = 25
b = 42
print(a)
print(b) #<br> 한줄씩 출력이 됨

#줄바꿈 처리 없이 한줄로 쓰고 싶다면?
print(a,end=' ')
print(b)
# Out:
# 25
# 42
# 25 42

# %%
print('안녕하세요')
print()  # 공백이 한줄을 차지
print('Python')
# Out:
# 안녕하세요
#
# Python

# %%
name = '홍길동'
age = 20
print('이름은',name,'이고 나이는',age,'입니다.')  #띄어쓰기가 기본적으로 포함되어있다 변수값 앞뒤로 / 불필요한 공백을 없애려면 print함수 안에 f-문자열을 입력
# Out:
# 이름은 홍길동 이고 나이는 20 입니다.

# %% [markdown]
# ### f-문자열(f-string):
# 문자열 앞에 소문자f 또는 대문자 F를 붙이고 문자열 안의 변수를 중괄호({})로 감싸서 표현하는 것
#
#
# *   변수 값이 출력되는 형식을 지정할수있음
# *   변수명 옆에 콜론(:)을 넣고 그다음에 형식을 지정
# *   중괄호 안의 d는 정수를 의미하고, f는 부동소수점수를 의미

# %%
#불필요한 띄어쓰기 x -> f-string
#문자열 앞에 소문자f 를 붙이고 문자열 안의 변수를 중괄호({})로 감싸서 표현하는 것
#print(f'문자열 {변수}')
#f-string을 쓰면 변수 값이 출력되는형식을 지정할 수 있음
name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age} 입니다')
print(f'{name:5}:{age:3}') #총 5칸, 총 3칸 홍길동xx:x20 문자열 왼쪽정렬, 숫자는 오른쪽정렬
# Out:
# 이름은 홍길동이고 나이는 20 입니다

# %%
a = 25
b= 1234
c = 4
print(f'{a:5d}') #a:5d 5칸,d는 정수형으로 숫자는 오른쪽정렬

print(f'{b:5d}') # 5칸, d는 정수형으로
print(f'20{c:02d}') #2칸, 정수형으로 출력 남는자리는 0으로 채워라
# Out:
#    25
#  1234
# 2004

# %%
a = 3.14159265
print(f'{a},{a:3f}')
print(f'{a:7.3f}') #7자리인데 소수점 3째자리에서 반올림해서
# Out:
# 3.14159265,3.141593
#   3.142

# %%
# 원의 넓이 구하는 식
pi = 3.14159265
radius = int(input('원의 반지름: '))
area = pi * radius ** 2 # pi * radius * radius
print(f'반지름이 {radius}인 원의넓이는 {area:.3f}')# 소수점 이하 소수점 3째자리에서 반올림한다
# Out:
# 원의 반지름: 5
# 반지름이 5인 원의넓이는 78.540

# %%
#bool형
a = 10 > 20
print(a)
# Out:
# False

# %%
#string문자형
a = 'python'
print(a)
# Out:
# python

# %%
#문자열 연결 연산자 +
print('Hi'+'Python')
# Out:
# HiPython

# %%
print('convergence'+'programming')
print(23 - 25)
print(1.23 + 12.3e-1) # 12.3e-1 => 1.23
# Out:
# convergenceprogramming
# -2
# 2.46

# %% [markdown]
# ## 4. 연산자 (Operators)
#
# 산술 연산자를 통해 데이터를 계산합니다.
#
# | 연산자 | 기능 | 예시 (a=10, b=3) | 결과 |
# | --- | --- | --- | --- |
# | `+` | 더하기 | `a + b` | 13 |
# | `-` | 빼기 | `a - b` | 7 |
# | `*` | 곱하기 | `a * b` | 30 |
# | `/` | 나누기 (실수) | `a / b` | 3.333... |
# | `//` | **몫** | `a // b` | 3 |
# | `%` | **나머지** | `a % b` | 1 |
# | `**` | 거듭제곱 | `a ** b` | 1000 |

# %%
# ** 거듭제곱 10 ** 3 => 10^3
a = int(input('정수: '))
b = int(input('정수: '))
print(f'{a} + {b} = {a+b}')

print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} // {b} = {a//b}') #몫
print(f'{a} % {b} = {a%b}') #나머지
print(f'{a} ** {b} = {a**b}') #6^4
# Out:
# 정수: 5
# 정수: 4
# 5 + 4 = 9
# 5 - 4 = 1
# 5 * 4 = 20
# 5 / 4 = 1.25
# 5 // 4 = 1
# 5 % 4 = 1
# 5 ** 4 = 625

# %% [markdown]
# ### 연산자  우선 순위
#
# 우선순위가 낮은 애를 먼저 계산하고싶을때 괄호로 묶어주기
#
# 우선순위와 관계없이 연산의 순서를 정하려면 **괄호** 를 사용해주기
#
#
# 1.   ** 거듭제곱
# 2.   +양수, -음수
# 3. *,/,//,%
# 4. +,-
# 5. <, <=, >, >= 비교연산자
# 6. ==,!= 동등연산자
# =,+=,-=,/=,//=,%=,**= 대입연산자
# 7. not 논리연산자
# 8. and 논리연산자
# 9. or 논리연산자

# %%
#잘모르겟다 -> 무조건 괄호 써주면 됨
ave = (70 + 80 + 90) / 3
print(ave)
# Out:
# 80.0

# %%
a = 2
b = 3
c = 4
print(a + b ** c * a) # 3^4 * 2 + 2
# Out:
# 164

# %%
# 남여 비율 계산하기
male_num = int(input('남성 지원자 수: '))
female_num = int(input('여성 지원자 수: '))
total = male_num + female_num
print(f'남성비율: {male_num / total:.2f} 여성비율: {female_num / total:.2f}') #소수점 둘째자리까지 반올림하여 출력
# Out:
# 남성 지원자 수: 173
# 여성 지원자 수: 217
# 남성비율: 0.44 여성비율: 0.56

# %%
# 길이 단위 변환하기
cm = int(input('센티미터 단위 길이: '))
m = cm // 100
cm = cm % 100
print(f'{m}미터 {cm}센티미터')
# Out:
# 센티미터 단위 길이: 234
# 2미터 34센티미터

# %% [markdown]
# ## 5. [실습 예제]
# ### ⏱ 시간 단위 변환기
# 1. **데이터 입력**: 사용자로부터 초(second) 단위의 큰 숫자를 입력받아 정수로 변환합니다.
# 2. **시간/분 계산**:
#     * 전체 초를 3,600으로 나눈 **몫**을 '시간'으로 저장합니다.
#     * 남은 초를 다시 60으로 나눈 **몫**은 '분', **나머지**는 최종적인 '초'가 됩니다.
# 3. **결과 출력**: 계산된 시간, 분, 초를 조합하여 화면에 보여줍니다.

# %%
# 실습예제
sec = int(input('초 단위 시간: '))
hour = sec // 3600
minute = (sec % 3600) // 60
sec = sec % 60
print(f'{hour}시간 {minute}분 {sec}초')
# Out:
# 초 단위 시간: 5000
# 1시간 23분 20초

# %%
#간단하게
second = int(input('초 단위 시간을 입력하세요: '))
hour = second // 3600 # 60s = 1m 60m = 1h, 3600s = 1s
second = second % 3600
minute = second // 60
second = second % 60
print(f'{hour}시간 {minute}분 {second}초' )
# Out:
# 초 단위 시간을 입력하세요: 8750
# 2시간 25분 50초

# %% [markdown]
# ### 💰 주문 금액 계산기
# 1. **정보 입력**: 상품 가격과 주문 수량을 각각 입력받아 숫자로 변환합니다.
# 2. **금액 산출**: (상품 가격 × 수량) 로직을 통해 총 주문 금액을 계산합니다.
# 3. **포맷팅**: "총 주문 금액은 OOO원입니다"와 같은 형태로 가독성 있게 출력합니다.

# %% [markdown]
# 1.주문금액 계산기
# <br>음료 주문 수 입력 받기
# *  americano 2000
# * latte 3000
# * greentea 2500
# 2.주문 금액 sum 출력

# %%
#주문금액 계산기
americano=int(input('아메리카노 몇잔:' ))
latte=int(input('라떼 몇잔:'))
greentea=int(input('녹차 몇잔'))

americano_price = 2000
latte_price = 3000
greentea_price = 2500

sum = (americano * americano_price) + (latte * latte_price) +(greentea * greentea_price)
print(f'총 {sum}원 입니다.')
# Out:
# 아메리카노 몇잔:3
# 라떼 몇잔:2
# 녹차 몇잔4
# 총 22000원 입니다.

# %% [markdown]
# ### 주문금액 계산기
#
# 1. 음료 가격을 변수에 저장
#
#
#
#   americaano_price = 2000<br>
#    latte_price = 3000<br>
#    greentea_price = 2500

# %%
americano_price = 2000
latte_price = 3000
greentea_price = 2500

sum = 0

americano_order = int(input('아메리카노 주문수: '))
sum += americano_price * americano_order

latte_order = int(input('라떼 주문수: '))
sum += latte_price * latte_order

greentea_order = int(input('녹차 주문수: '))
sum += greentea_price * greentea_order

print(f'총 주문수는 {sum}원 입니다.')
# Out:
# 아메리카노 주문수: 3
# 라떼 주문수: 4
# 녹차 주문수: 5
# 총 주문수는 30500원 입니다.
