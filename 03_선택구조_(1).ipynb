# %% [markdown]
# <a href="https://colab.research.google.com/github/jihye-jeon2/python/blob/main/03_%EC%84%A0%ED%83%9D%EA%B5%AC%EC%A1%B0_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 파이썬 기초: 03. 선택 구조

# %% [markdown]
# ## 1. 비교 연산자 (Comparison Operators)
# * **개념**: 두 값의 크기를 비교하여 참(`True`) 또는 거짓(`False`)을 결과로 반환하는 연산자입니다.
# * **주요 연산자**:
#     * `==` : 같다
#     * `!=` : 다르다
#     * `>` / `<` : 크다 / 작다
#     * `>=` / `<=` : 크거나 같다 / 작거나 같다

# %%
a, b, c = 10,20,20
print(f'{a}=={b}: {a == b}') #앞에는 문자열 뒤에는 수식
print(f'{a}!={b}: {a!=b}')
print(f'{a}>{b}: {a>b}')
print(f'{b}<{c}: {b<c}')
print(f'{a}>={b}: {a>=b}')
print(f'{b}<={c}: {b<=c}')
# Out:
# 10==20: False
# 10!=20: True
# 10>20: False
# 20<20: False
# 10>=20: False
# 20<=20: True

# %% [markdown]
# ### random 라이브러리
#
# import random <br>
# random.함수이름() <br>
# randint(시작값, 끝값) : 정수 중 하나를 무작위로 반환

# %%
import random

a = random.randint(1,5)
answer = int(input('랜덤 수를 맞혀보세요(1-5): '))
print(f'결과는: {a == answer}, 랜덤 수는 {a}') #비교연산자는 True or False로 결과 반환
# Out:
# 랜덤 수를 맞혀보세요(1-5): 3
# 결과는: False, 랜덤 수는 5

# %%
# 무작위로 정수 2개(a,b)를 생성한 다음에 a나누기b의 몫과 나머지를 출력
#a, b
#my_quotient 몫을 예측한 값을 입력
#my_remainder 나머지를 예측한 값을 입력
# 실제 값과 예측값을 비교해서 출력: True, False

# %%
from binascii import b2a_base64
import random
a = random.randint(10,50)
b = random.randint(2,9)

my_quotient = int(input('몫 예측값 {a//b}'))
my_remainder = int(input('나머지 예측값 {a%b}'))

real_quotient = a//b
real_remainder = a%b

print(f'{my_quotient == real_quotient}')
print(f'{my_remainder == real_remainder} ')
# Out:
# 몫 예측값 a/b5
# 나머지 예측값 a%b3
# False
# False

# %% [markdown]
# ## 2. 선택 구조 (Selection Structure)
# * **개념**: 조건식의 결과에 따라 실행할 문장을 결정하는 구조입니다.
# * **if 문**: 조건이 참일 때만 실행할 문장을 작성합니다.
# * **if-else 문**: 조건이 참일 때와 거짓일 때 실행할 문장을 각각 나누어 작성합니다.
# * **if-elif-else 문**: 여러 개의 조건을 순차적으로 체크해야 할 때 사용합니다.
# * **주의 사항**:
#     * 조건문 끝에는 반드시 **콜론(:)**을 붙여야 합니다.
#     * 실행할 문장은 반드시 **들여쓰기(Indentation)**를 해야 합니다.

# %% [markdown]
# ### if 문
#
# ```
# # if 조건식1:
#   실행문1
# ```
# ---
# ### if-else문
#
# ```
# # if 조건식1:
#   실행문1
# else:
#   실행문2
# ```
#
# ---
#
# ### if-elif-else 조건이 3개이상일때
# ```
# # if 조건식1:
#   실행문1
# elif 조건식2:
#   실행문2
# else:
#   실행문3
#
# ```

# %%
import random
a = random.randint(1,100)
b = random.randint(1,100)
print(a,b)

if a<b:
  a,b = b,a # 실행할 문장 들여쓰기 꼭하기
print(a,b)
# Out:
# 87 94
# 94 87

# %%
#if-else문
height1 = int(input('키: '))
height2 = int(input('키: '))

if height1 > height2:
  print(f'키차이: {height1-height2}')
else:
  print(f'키차이:{height2-height1}')

#if 조건식:
   #문장1
#else:
  #문장2
# Out:
# 키: 190
# 키: 170
# 키차이: 20

# %%
#if~elif~else // 결과값이 3개 이상일때
#if 조건식1:
  #문장1
#elif 조건식2:
  #문장2:
#else:
  #문장3
fee = 5000
age = int(input('나이: '))

if age < 8:
  print('입장료: {fee*0.7}')
elif age < 60:
  print('입장료 : {fee}')
else :
  print('입장료: {fee*0.8}')
# Out:
# 나이: 20
# 입장료 : {fee}

# %% [markdown]
# ###문제:가격할인
# 입력받은 가격이 10,000원 이상일때 판매가에서 5%할인 그렇지 않으면 할인하지 않음 price

# %%
##문제: 가격할인
price=int(input('가격: '))

if price>=10000:
  print(f'가격: {price*0.95}')
else:
  print(f'가격:{price}')
# Out:
# 가격: 20000
# 가격: 19000.0

# %% [markdown]
# ### 문제: 짝수와홀수판별하기
# 사용자로부터 입력받은 정수가 짝수인지 홀수인지 출력하기

# %%
##문제: 짝수 홀수 판별
num = int(input('숫자입력: '))
if num%2 ==0:
  print(f'{num}은 짝수')
else:
  print(f'{num}은 홀수')
# Out:
# 숫자입력: 5
# 5은 홀수

# %% [markdown]
# ### 문제: 주사위 굴리기
# 랜덤으로 1~6사이의 숫자를 구해서 숫자 2개를준비
# 각숫자 출력하고
# 첫번째 숫자가 크면 주사위1승
# 두번째숫자가 크면 주사위2승 출력
# 그렇지 않으면 무승부 출력

# %%
##문제: 주사위 굴리기
import random
dice1 = random.randint(1,6)
dice2 = random.randint(1,6)

print(f'주사위1: {dice1}')
print(f'주사위2: {dice2}')

if dice1>dice2:
  print('주사위1승')
elif dice1<dice2:
  print('주사위2승')
else:
  print('무승부')
# Out:
# 주사위1: 4
# 주사위2: 2
# 주사위1승

# %% [markdown]
# ###문제: 스포츠스태킹 개인 기록정하기
# 입력받은 3개의 수중에서 가장 작은수를 정해서 개인기록으로 정하기

# %%
score1 =int(input('점수1: '))
score2 = int(input('점수2: '))
score3 = int(input('점수3: '))

if score1<score2 and score1<score3:
  print(f'개인기록:{score1}')
elif score2<score1 and score2<score3:
  print(f'개인기록: {score2}')
else:
  print(f'개인기록: {score3}')
# Out:
# 점수1: 8
# 점수2: 7
# 점수3: 4
# 개인기록: 4

# %%
score1 = int(input('점수1: '))
score2 = int(input('점수2: '))
score3 = int(input('점수3: '))

if score1<score2:
  if score1<score3:
    print(f'개인기록: {score1}')
  else :
    print(f'개인기록: {score3}')
else:
  if score2<score3:
    print(f'개인기록: {score2}')
  else:
    print(f'개인기록: {score3}')
# Out:
# 점수1: 3
# 점수2: 4
# 점수3: 5
# 개인기록: 3

# %% [markdown]
# ## 3. 논리 연산자 (Logical Operators)
# * **개념**: 여러 개의 조건식을 조합하여 하나의 결과를 얻을 때 사용합니다.
# * **종류**:
#     * `and` : 두 조건이 모두 참일 때만 참
#     * `or` : 두 조건 중 하나만 참이어도 참
#     * `not` : 참을 거짓으로, 거짓을 참으로 반전

# %%
a=25
print(a>=8 and a<60)

a = 70
print(a<8 or a>=60)

a=20
print(not a==20)
# Out:
# True
# True
# False

# %%
##문제 쇼핑몰 회원별 결제금액 계산하기
level = input('회원등급: ')
price = int(input('구매액: '))
delivery_fee = 2000

if level == '우수' or  price >= 20000:
  print(f'결제금액: {price}')
else:
  print(f'결제금액: {price+delivery_fee}')
# Out:
# 회원등급: 일반
# 구매액: 20100
# 결제금액: 22100

# %% [markdown]
# ### 쇼핑몰 회원별 결제금액 계산하기
#
#
# *   회원등급을 입력 받음 (우수 또는 일반)
# *   구매액을 입력 받음
# *   기본 배송비 2000원
# *   우수고객이거나 2만원이상 구매자는 배송비가 무료
# *   결제금액출력(배송비포함)

# %%
# 정수 입력받아서 3의배수인지 5의배수인지 출력
num = int(input('정수입력: '))

if num % 15 ==0 :
  print(f'{num}은 3의배수이고 5의배수')
else:
  print(f'{num}')
# Out:
# 정수입력: 45
# 45은 3의배수이고 5의배수

# %%
# 정수 입력받아서 3의배수인지 5의배수인지 출력
a=int(input('정수: '))

if a%3==0 and a%5==0:
  print(f'{a}는 3과 5의배수')
else:
  print(f'{a}')
# Out:
# 정수: 45
# 45는 3과 5의배수

# %%
# 연도를 입력 받아서 윤년인지 평년인지 판별
#윤년(2/29일이 있는 년도)은 4년에 한번, 400년에 한번, 100년째 해는 윤년이 아님

year = int(input('연도: '))

if (year%4==0 and year%100!=0) or (year%400==0):
  print(f'{year}은 윤년인 해')
else:
  print(f'{year}')
# Out:
# 연도: 800
# 800은 윤년인 해

# %%
#가위바위보 게임
import random

user = input('가위,바위,보: ')
com_rand = random.randint(1,3)

if com_rand == 1:
  computer = '가위'
elif com_rand == 2:
  computer = '바위'
else:
  computer = '보'

print(f'유저: {user} 컴퓨터: {computer}')

if user == computer:
  print('무승부')
elif user == '가위':
  if computer == '바위':
    print('컴퓨터 승')
  else:
    print('유저 승')
elif user == '바위':
  if computer == '보':
    print('컴퓨터 승')
  else:
    print('유저 승')
elif user == '보':
  if computer =='가위':
    print('컴퓨터 승')
  else:
    print('유저 승')
# Out:
# 가위,바위,보: 가위
# 유저: 가위 컴퓨터: 바위
# 컴퓨터 승

# %% [markdown]
# ## 4. 함수 (Function)
# * **개념**: 특정 작업을 수행하는 명령어들의 묶음입니다.
# * **라이브러리 활용**: `import` 키워드를 사용하여 외부 도구(라이브러리)를 불러올 수 있습니다.
# * **랜덤 함수**: `random.randint(start, end)`는 지정한 범위 내의 정수 중 하나를 무작위로 반환합니다.

# %%
import random

def rand_add(): #함수를 정의하겠다 rand_add라는 함수임
  a = random.randint(1,100)
  b = random.randint(1,100) #들여쓰기
  answer = int(input(f'{a}+{b}: '))

  if answer == a+b:
    print('정답입니다!')
  else:
    print('틀렸습니다.')

rand_add()
rand_add()   #함수를 호출함
# Out:
# 45+13: 58
# 정답입니다!
# 65+97: 162
# 정답입니다!

# %% [markdown]
# ### 함수 정의
#
#
#
# ```
# def 함수이름(매개변수1,매개변수2):
#   실행문
#   return 반환값
#
#   ```
#
#   ### 함수 호출
#
#   함수이름(인자값1,인자값2)

# %% [markdown]
# ### 사칙연산 함수 만들기
#
#
# *   함수이름 add,sub,mul,duv
# *   a,b두개의 정수 입력받기
# *  각 함수 호출해서 출력
# *  a+b =덧셈함수 호출

# %%
from typing import DefaultDict
import random
a = int(input(' a 정수입력: '))
b = int(input('b 정수입력: '))

def add(a,b):
  return a+b

def sub(a,b):
  return a-b

def mul(a,b):
  return a*b

def div(a,b):
 return a/b

print(f'a + b = {add(a,b)}')
# Out:
#  a 정수입력: 5
# b 정수입력: 3
# a + b = 8

# %%
#div 함수에서 몫, 나머지 반환
# 변수 몫 quotient,나머지 remainder
from ast import Yield
def div(x,y):
  return x//y, x%y  #리턴값이 두개, 변수값 2개

a = int(input('a: '))
b = int(input('b: '))


quotient, remainder = div(a,b)
print(f'a를b로 나눈 몫은 {quotient}이고 나머지는 {remainder}이다.')
# Out:
# a: 8
# b: 5
# a를b로 나눈 몫은 1이고 나머지는 3이다.

# %% [markdown]
# ## 5. [실습 예제]
#
# ### 🌡️ 온도 변환기 (온도 종류 통합형)
# 1. **입력**: 사용자로부터 온도 종류(섭씨 또는 화씨)와 온도 값을 입력받습니다.
# 2. **판단 및 계산**:
#     * `if kind == '섭씨':` 이면 화씨 공식(`temp * 1.8 + 32`)으로 계산합니다.
#     * `else:` 이면 화씨로 간주하고 섭씨 공식(`(temp - 32) / 1.8`)으로 계산합니다.
# 3. **출력**: 변환된 온도 결과를 화면에 표시합니다.

# %%
#실습문제
kind = input('온도종류: ')
temp = int(input('온도: '))

if kind == '섭씨':
  print(f'화씨F온도: {temp*18/10 + 32}')
else:

  print(f'섭씨C온도: {(temp - 32) * 10/18}')
# Out:
# 온도종류: 화씨
# 온도: 23
# 섭씨온도: -5.0

# %%
celsious = int(input('섭씨온도: '))
# Out:
# 섭씨온도: 23

# %%
#섭씨온도를 화씨온도로 변환
celsious*1.8 + 32
# Out:
# 73.4

# %%
fahrenheit = int(input('화씨온도'))
# Out:
# 화씨온도23

# %%
# 화씨온도를 섭씨온도로 변환
(fahrenheit-32) / (1.8)
# Out:
# -5.0

# %% [markdown]
# # 새 섹션

# %% [markdown]
# ### 📐 두 도형의 넓이 비교하기
# 1. **계산**: 사각형(가로×세로)과 삼각형(밑변×높이/2)의 정보를 각각 입력받아 넓이를 구합니다.
# 2. **비교**:
#     * `if 넓이1 > 넓이2:` 첫 번째 도형이 더 넓다고 출력합니다.
#     * `elif 넓이1 < 넓이2:` 두 번째 도형이 더 넓다고 출력합니다.
#     * `else:` 두 도형의 넓이가 같다고 출력합니다.

# %%
from re import S
import math
# 사각형square, 삼각형triangle, 원 함수circle 3개
#사각형은 가로 세로 입력받아서 넓이는 가로*세로 값 반환
#삼각형은 밑변base 높이height 입력받아서 넓이는 밑변*높이/2 값 반환
#원은 반지름 radius입력받아서 math.pi*반지름*반지름(라이브러리 사용 import math)
def square_area(square_width,square_height):
  return square_width*square_height
def triangle_area(base,triangle_height1):
  return base* triangle_height1* 1/2
def circle_area(radius):
  return math.pi*radius*radius

square_width = int(input('사각형 가로값: '))
height = int(input('사각형 세로값: '))

base= int(input('삼각형 밑변'))
triangle_height1=int(input('삼각형높이'))

radius = int(input('원 반지름: '))

# 함수를 호출하고 그 결과를 변수에 저장합니다.
calculated_square_area = square_area(square_width, height)
calculated_triangle_area = triangle_area(base, triangle_height1)
calculated_circle_area = circle_area(radius)

# 이제 계산된 넓이 값을 사용하여 비교합니다.
if  calculated_square_area > calculated_triangle_area > calculated_circle_area:
  print(f'사각형 넓이 1등, 2등 삼각형보다: {calculated_square_area-calculated_triangle_area:.2f},3등 원보다: {calculated_square_area-calculated_circle_area:.2f}')
elif calculated_square_area > calculated_circle_area > calculated_triangle_area:
  print(f'사각형 넓이 1등,2등 원보다: {calculated_square_area-calculated_circle_area:.2f},3등 삼각형보다: {calculated_square_area-calculated_triangle_area:.2f}')
elif calculated_square_area > calculated_triangle_area and calculated_triangle_area == calculated_circle_area:
  print(f'사각형 넓이 1등, 원,삼각형 넓이 동일,{calculated_square_area-calculated_circle_area:.2f}만큼더큼')
elif calculated_triangle_area > calculated_square_area > calculated_circle_area:
  print(f'삼각형넓이1등,2등 사각형보다{calculated_triangle_area-calculated_square_area:.2f},3등 원보다{calculated_triangle_area-calculated_circle_area:.2f}')
elif calculated_triangle_area > calculated_circle_area > calculated_square_area:
  print(f'삼각형넓이1등,2등 원보다{calculated_triangle_area-calculated_circle_area:.2f},3등 사각형보다 {calculated_triangle_area-calculated_square_area:.2f}')
elif calculated_triangle_area > calculated_square_area and calculated_square_area == calculated_circle_area:
  print(f'삼각형넓이 1등, 원,사각형 넓이 동일, {calculated_triangle_area-calculated_circle_area:.2f}만큼')
elif calculated_circle_area > calculated_square_area > calculated_triangle_area:
  print(f'원넓이1등,2등 사각형보다{calculated_circle_area-calculated_square_area:.2f},3등 삼각형보다{calculated_circle_area-calculated_triangle_area:.2f}')
elif calculated_circle_area > calculated_triangle_area > calculated_square_area:
  print(f'원넓이1등,2등 삼각형보다{calculated_circle_area-calculated_triangle_area:.2f},3등 사각형보다{calculated_circle_area-calculated_square_area:.2f}')
elif calculated_circle_area > calculated_square_area and calculated_square_area == calculated_triangle_area:
  print(f'원넓이 1등, 사각형,삼각형 넓이 동일, {calculated_circle_area-calculated_triangle_area:.2f}만큼더큼')
else:
  print('모든 도형의 넓이 같음')
# Out:
# 사각형 가로값: 3
# 사각형 세로값: 4
# 삼각형 밑변3
# 삼각형높이4
# 원 반지름: 5
# 원넓이1등,2등 사각형보다66.54,3등 삼각형보다72.54
